# %%
import pandas as pd
import numpy as np
import pandas_profiling
import re

# %%
salaries_by_college_major_df = pd.read_csv('C:/Users/xinwa/OneDrive/Documents/Data Science/Capstone Project 2/data/degrees-that-pay-back.csv')
print(salaries_by_college_major_df.shape)
print(salaries_by_college_major_df.dtypes)
salaries_by_college_major_df.head()
# Out:
# (50, 8)
# Undergraduate Major                                   object
# Starting Median Salary                                object
# Mid-Career Median Salary                              object
# Percent change from Starting to Mid-Career Salary    float64
# Mid-Career 10th Percentile Salary                     object
# Mid-Career 25th Percentile Salary                     object
# Mid-Career 75th Percentile Salary                     object
# Mid-Career 90th Percentile Salary                     object
# dtype: object
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
# ...

# %%
salaries_by_college_major_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Undergraduate Major                                50 non-null     object
#  1   Starting Median Salary                             50 non-null     object
#  2   Mid-Career Median Salary                           50 non-null     object
#  3   Percent change from Starting to Mid-Career Salary  50 non-null     float64
#  4   Mid-Career 10th Percentile Salary                  50 non-null     object
#  5   Mid-Career 25th Percentile Salary                  50 non-null     object
#  6   Mid-Career 75th Percentile Salary                  50 non-null     object
#  7   Mid-Career 90th Percentile Salary                  50 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 3.2+ KB

# %% [markdown]
# There is no null value in salaries_by_college_major_df

# %%
len(pd.unique(salaries_by_college_major_df['Undergraduate Major']))
# Out:
# 50

# %% [markdown]
# no duplicate majors

# %%
# covert column of strings into column of floats
def convert_str_column_to_numeric(df, column_list):
    for column in column_list:
        df[column] = pd.to_numeric(df[column].str.replace('[$,]', '', regex=True))

# %%
column_list = ['Starting Median Salary', 'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary', \
               'Mid-Career 25th Percentile Salary', 'Mid-Career 75th Percentile Salary', 'Mid-Career 90th Percentile Salary']

# %%
convert_str_column_to_numeric(salaries_by_college_major_df, column_list)
salaries_by_college_major_df.dtypes
# Out:
# Undergraduate Major                                   object
# Starting Median Salary                               float64
# Mid-Career Median Salary                             float64
# Percent change from Starting to Mid-Career Salary    float64
# Mid-Career 10th Percentile Salary                    float64
# Mid-Career 25th Percentile Salary                    float64
# Mid-Career 75th Percentile Salary                    float64
# Mid-Career 90th Percentile Salary                    float64
# dtype: object

# %%
salaries_by_college_type_df = pd.read_csv('C:/Users/xinwa/OneDrive/Documents/Data Science/Capstone Project 2/data/salaries-by-college-type.csv')
print(salaries_by_college_type_df .shape)
salaries_by_college_type_df .head()
# Out:
# (269, 8)
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $62,400.00              $114,000.00
# 4             $62,200.00              $114,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $76,800.00                        $99,200.00
# 1                               NaN                       $104,000.00
# ...

# %%
salaries_by_college_type_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   School Name                        269 non-null    object
#  1   School Type                        269 non-null    object
#  2   Starting Median Salary             269 non-null    object
#  3   Mid-Career Median Salary           269 non-null    object
#  4   Mid-Career 10th Percentile Salary  231 non-null    object
#  5   Mid-Career 25th Percentile Salary  269 non-null    object
#  6   Mid-Career 75th Percentile Salary  269 non-null    object
#  7   Mid-Career 90th Percentile Salary  231 non-null    object
# dtypes: object(8)
# memory usage: 16.9+ KB

# %% [markdown]
# column 'Mid-Career 10th Percentile Salary' and clumn 'Mid-Career 90th Percentile Salary' have null values

# %%
len(pd.unique(salaries_by_college_type_df['School Name']))
# Out:
# 249

# %% [markdown]
# there are duplicate school names

# %%
salaries_by_college_type_df.dtypes
# Out:
# School Name                          object
# School Type                          object
# Starting Median Salary               object
# Mid-Career Median Salary             object
# Mid-Career 10th Percentile Salary    object
# Mid-Career 25th Percentile Salary    object
# Mid-Career 75th Percentile Salary    object
# Mid-Career 90th Percentile Salary    object
# dtype: object

# %%
convert_str_column_to_numeric(salaries_by_college_type_df, column_list)
salaries_by_college_type_df.dtypes
# Out:
# School Name                           object
# School Type                           object
# Starting Median Salary               float64
# Mid-Career Median Salary             float64
# Mid-Career 10th Percentile Salary    float64
# Mid-Career 25th Percentile Salary    float64
# Mid-Career 75th Percentile Salary    float64
# Mid-Career 90th Percentile Salary    float64
# dtype: object

# %%
count_na_in_10th_percentile_college_type=salaries_by_college_type_df['Mid-Career 10th Percentile Salary'].isna().sum()
count_na_in_90th_percentile_college_type=salaries_by_college_type_df['Mid-Career 90th Percentile Salary'].isna().sum()
count_na_in_both = salaries_by_college_type_df[(salaries_by_college_type_df['Mid-Career 10th Percentile Salary'].isna()) & \
                                         (salaries_by_college_type_df['Mid-Career 90th Percentile Salary'].isna())].shape[0]
count_na_in_10th_percentile_college_type, count_na_in_90th_percentile_college_type, count_na_in_both
# Out:
# (38, 38, 38)

# %%
print("The percentage of null values in columns: "+"{:.2%}".format(38/len(salaries_by_college_type_df)))
# Out:
# The percentage of null values in columns: 14.13%

# %%
salaries_by_college_type_report = salaries_by_college_type_df.profile_report(sort=None, html={'style':{'full_width': True}}, progress_bar=False)
salaries_by_college_type_report
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-06-13 03:39:51.623192&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Series of booleans
school_names=((salaries_by_college_type_df.groupby('School Name').count()>1).sum(axis=1)>1)
school_names
# Out:
# School Name
# Amherst College                          False
# Appalachian State University             False
# Arizona State University (ASU)            True
# Arkansas State University (ASU)          False
# Auburn University                        False
#                                          ...
# Whitman College                          False
# Williams College                         False
# Wittenberg University                    False
# Worcester Polytechnic Institute (WPI)    False
# Yale University                          False
# Length: 249, dtype: bool

# %%
salaries_by_college_type_df.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0                 72200.0                  126000.0
# 1                 75500.0                  123000.0
# 2                 71800.0                  122000.0
# 3                 62400.0                  114000.0
# 4                 62200.0                  114000.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                            76800.0                            99200.0
# 1                                NaN                           104000.0
# ...

# %%
salaries_by_college_type_df[salaries_by_college_type_df['School Name'].duplicated(keep=False)].sort_values('School Name')
# Out:
#                                            School Name   School Type  \
# 142                     Arizona State University (ASU)         State
# 28                      Arizona State University (ASU)         Party
# 38                      Florida State University (FSU)         Party
# 214                     Florida State University (FSU)         State
# 29                Indiana University (IU), Bloomington         Party
# 144               Indiana University (IU), Bloomington         State
# 25                    Louisiana State University (LSU)         Party
# 120                   Louisiana State University (LSU)         State
# 211                                    Ohio University         State
# 37                                     Ohio University         Party
# 27                 Pennsylvania State University (PSU)         Party
# 128                Pennsylvania State University (PSU)         State
# 67                              Randolph-Macon College  Liberal Arts
# ...

# %%
salaries_by_college_type_df[salaries_by_college_type_df['School Type']=='Party']
# Out:
#                                           School Name School Type  \
# 19  University of Illinois at Urbana-Champaign (UIUC)       Party
# 20               University of Maryland, College Park       Party
# 21     University of California, Santa Barbara (UCSB)       Party
# 22                  University of Texas (UT) - Austin       Party
# 23      State University of New York (SUNY) at Albany       Party
# 24                         University of Florida (UF)       Party
# 25                   Louisiana State University (LSU)       Party
# 26                        University of Georgia (UGA)       Party
# 27                Pennsylvania State University (PSU)       Party
# 28                     Arizona State University (ASU)       Party
# 29               Indiana University (IU), Bloomington       Party
# 30                            University of Iowa (UI)       Party
# 31                             Randolph-Macon College       Party
# ...

# %%
salaries_by_region_df = pd.read_csv('C:/Users/xinwa/OneDrive/Documents/Data Science/Capstone Project 2/data/salaries-by-region.csv')
print(salaries_by_region_df .shape)
salaries_by_region_df.head()
# Out:
# (320, 8)
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $70,400.00              $129,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $59,900.00              $112,000.00
# 4             $51,900.00              $105,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $68,400.00                        $93,100.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# ...

# %%
salaries_by_region_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   School Name                        320 non-null    object
#  1   Region                             320 non-null    object
#  2   Starting Median Salary             320 non-null    object
#  3   Mid-Career Median Salary           320 non-null    object
#  4   Mid-Career 10th Percentile Salary  273 non-null    object
#  5   Mid-Career 25th Percentile Salary  320 non-null    object
#  6   Mid-Career 75th Percentile Salary  320 non-null    object
#  7   Mid-Career 90th Percentile Salary  273 non-null    object
# dtypes: object(8)
# memory usage: 20.1+ KB

# %% [markdown]
# column 'Mid-Career 10th Percentile Salary' and clumn 'Mid-Career 90th Percentile Salary' have null values

# %%
len(pd.unique(salaries_by_region_df['School Name']))
# Out:
# 320

# %%
count_na_in_10th_percentile_region=salaries_by_region_df['Mid-Career 10th Percentile Salary'].isna().sum()
count_na_in_90th_percentile_region=salaries_by_region_df['Mid-Career 90th Percentile Salary'].isna().sum()
count_na_in_both = salaries_by_region_df[(salaries_by_region_df['Mid-Career 10th Percentile Salary'].isna()) & \
                                         (salaries_by_region_df['Mid-Career 90th Percentile Salary'].isna())].shape[0]
count_na_in_10th_percentile_region, count_na_in_90th_percentile_region, count_na_in_both
# Out:
# (47, 47, 47)

# %% [markdown]
# null values in column 'Mid-Career 10th Percentile Salary' and clumn 'Mid-Career 90th Percentile Salary' always show on
# the same rows in salaries_by_region_df

# %%
print("The percentage of null values in columns: "+"{:.2%}".format(47/len(salaries_by_region_df)))
# Out:
# The percentage of null values in columns: 14.69%

# %%
salaries_by_region_df.dtypes
# Out:
# School Name                          object
# Region                               object
# Starting Median Salary               object
# Mid-Career Median Salary             object
# Mid-Career 10th Percentile Salary    object
# Mid-Career 25th Percentile Salary    object
# Mid-Career 75th Percentile Salary    object
# Mid-Career 90th Percentile Salary    object
# dtype: object

# %%
convert_str_column_to_numeric(salaries_by_region_df, column_list)
salaries_by_region_df.dtypes
# Out:
# School Name                           object
# Region                                object
# Starting Median Salary               float64
# Mid-Career Median Salary             float64
# Mid-Career 10th Percentile Salary    float64
# Mid-Career 25th Percentile Salary    float64
# Mid-Career 75th Percentile Salary    float64
# Mid-Career 90th Percentile Salary    float64
# dtype: object

# %%
# drop 'Mid-Career 10th Percentile Salary' and 'Mid-Career 90th Percentile Salary' 
# from salaries_by_region_df and salaries_by_college_type_df
drop_column_list=['Mid-Career 10th Percentile Salary', 'Mid-Career 90th Percentile Salary']
salaries_by_college_type_clean_df=salaries_by_college_type_df.drop(drop_column_list, axis=1)
salaries_by_region_clean_df = salaries_by_region_df.drop(drop_column_list, axis=1)
salaries_by_college_type_clean_df.columns, salaries_by_region_clean_df.columns
# Out:
# (Index(['School Name', 'School Type', 'Starting Median Salary',
#         'Mid-Career Median Salary', 'Mid-Career 25th Percentile Salary',
#         'Mid-Career 75th Percentile Salary'],
#        dtype='object'),
#  Index(['School Name', 'Region', 'Starting Median Salary',
#         'Mid-Career Median Salary', 'Mid-Career 25th Percentile Salary',
#         'Mid-Career 75th Percentile Salary'],
#        dtype='object'))

# %%
# save the data to a new csv file
datapath = 'C:/Users/xinwa/OneDrive/Documents/Data Science/Capstone Project 2/data/'
salaries_by_college_type_clean_df.to_csv(datapath+'salaries_by_college_type_cleaned.csv', header= True, index=False)
salaries_by_region_clean_df.to_csv(datapath+'salaries_by_region_cleaned.csv', header= True, index=False)
